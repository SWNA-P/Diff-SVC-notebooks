# %% [markdown]
# <a href="https://colab.research.google.com/github/haru0l/Diff-SVC-notebooks/blob/main/Diff_SVC_training_notebook_(colab_ver_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Training notebook for [Diff-SVC](https://github.com/prophesier/diff-svc) written by [Nekro](https://twitter.com/NekroTheCorpse) of [Archivoice](https://github.com/archivoice)

# %% [markdown]
# # Check Setup

# %%
#@title #Check GPU type
#@markdown this is for checking the GPU type you have as well as the available amount of vram.
# !nvidia-smi -L
# !nvidia-smi

# %%
#@title #Mount Google Drive

#@markdown Makes your life easier when uploading and saving stuff.

from google.colab import drive
drive.flush_and_unmount()
# !rm -rf /content/drive
drive.mount('/content/drive')
print('Done!')

# %% [markdown]
# # Preparation

# %%
#@title #Step 1: Install Diff-SVC
#@markdown The stuff you'll need for every other thing afterwards.
from IPython.display import clear_output
from pySmartDL import SmartDL
import os
print('Upgrading pip & installing 7zip')
# !rm -rf /content/sample_data
# !python -m pip install --upgrade pip
# !python -m pip install --upgrade wheel
# !apt-get install unzip
# !pip install gdown
# !pip install pySmartDL
# !pip uninstall gdown -y
# !pip install git+https://github.com/justinjohn0306/gdown.git

print('Installing torch')
# %pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# !pip install --pre torchtext==0.6.0 --no-deps

#@markdown ---
#@markdown ###Select which fork to use
#@markdown The official repo is up-to-date, while UtaUtaUtau's version has Harvest support for improved f0.
fork = 'Official Diff-SVC Repo' #@param ["Official Diff-SVC Repo", "UtaUtaUtau's Repo"]

print('Installing Diff-SVC')
if fork == "Official Diff-SVC Repo":
  # !git clone https://github.com/prophesier/diff-svc
else:
  # !git clone --branch harvest-preprocess https://github.com/UtaUtaUtau/diff-svc
# %cd 

print('Installing requirements')
# %cd "/content/diff-svc/"
# !pip install -r requirements_short.txt
# !pip install tensorboard<2.9,>=2.8
# %reload_ext tensorboard

# %cd "/content/diff-svc/training/"
# !rm config.yaml
# !wget https://github.com/haru0l/Diff-SVC-notebooks/releases/download/checkpoints/config.yaml -O config.yaml
# %cd "/content/"
checkpoint = SmartDL("https://github.com/haru0l/Diff-SVC-notebooks/releases/download/checkpoints/checkpoints.zip", "/content/")
checkpoint.start()
# %mkdir -p /content/diff-svc/checkpoints/
# !unzip /content/checkpoints.zip -d /content/diff-svc/

#@markdown ---
#@markdown ###Use custom save directory
#@markdown You can change the directory to save wherever you want. Default location is /diff-svc/checkpoint if unchanged.

#@markdown Please point to a directory with the singer name already specified (example /content/drive/MyDrive/diff-svc/nyaru)

use_save_dir = False #@param {type: "boolean"}

save_dir = "" #@param {type: "string"}
save_dir = save_dir.replace(" ", "_")

if use_save_dir:
  # %cd /content/diff-svc/utils
  # !rm -rf hparams.py
  # !wget https://github.com/prophesier/diff-svc/raw/main/utils/hparams.py
  # !sed -i -r 's|checkpoints/\{args.work_dir}|haruwashere|g' /content/diff-svc/utils/hparams.py
  # !sed -i -r 's|haruwashere|{save_dir}|g' /content/diff-svc/utils/hparams.py
  # %cd /content/
else:
  # %cd /content/diff-svc/utils
  # !rm -rf hparams.py
  # !wget https://github.com/prophesier/diff-svc/raw/main/utils/hparams.py
  # %cd /content/

#clear_output()
print('Done!')

# %%
#@title #Step 2: Decompress dataset
#@markdown This should work with most common archive formats, so don't worry. Please stick with the alphabet characters otherwise preprocessing might error out.

#@markdown Supported types: `.rar`, `.zip`, `.tar`, `.tar.gz`, `.tar.bz2`, `.7z`

#@markdown ###Note that your dataset should consist of `.wav` or `.ogg` format audio
#@markdown ---
#@markdown Name your singer.
singer_name = 'Unnamed' #@param {type: "string"}
singer_name = singer_name.replace(" ", "_")
# %cd "/content/"
# !sed -i -r 's/atri/{singer_name}/g' /content/diff-svc/training/config.yaml

#@markdown ---
#@markdown File location
# !mkdir -p /content/diff-svc/data/raw
dataset_location = '/content/drive/MyDrive/*' #@param {type: "string"}
diffsvc_location = os.path.join('diff-svc', 'data', 'raw', singer_name, "")

if dataset_location.endswith('.rar'):
    # !unrar x "$dataset_location" "$diffsvc_location"
elif dataset_location.endswith('.zip'):
    # !unzip "$dataset_location" -d "$diffsvc_location"
elif dataset_location.endswith('.tar'):
    # !tar -xf "$dataset_location" -C "$diffsvc_location"
elif dataset_location.endswith('.tar.gz'):
    # !tar -xzf "$dataset_location" -C "$diffsvc_location"
elif dataset_location.endswith('.tar.bz2'):
    # !tar -xjf "$dataset_location" -C "$diffsvc_location"
else:
    !7za x "$dataset_location" -o$diffsvc_location

print('Done!')

# %%
#@title #Step 2-A: Decompress training data
#@markdown Decompresses training data directly to `diff-svc/data/binary`, usable only if you already have the output files of Step 4.

#@markdown Supported types: check above. 

#@markdown ###You must match the training settings of the config.yaml file you used to generated the preprocessed data.
#@markdown ---
#@markdown Name your singer.
singer_name = 'Unnamed' #@param {type: "string"}
singer_name = singer_name.replace(" ", "_")
# !sed -i -r 's/atri/{singer_name}/g' /content/diff-svc/training/config.yaml

#@markdown ---
#@markdown File location
# !mkdir -p /content/diff-svc/data/binary
preprocessed_data_location = '/content/drive/MyDrive/*' #@param {type: "string"}
diffsvc_bin_location = '/content/diff-svc/data'

if preprocessed_data_location.endswith('.rar'):
    # !unrar x "$preprocessed_data_location" "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.zip'):
    # !unzip "$preprocessed_data_location" -d "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.tar'):
    # !tar -xf "$preprocessed_data_location" -C "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.tar.gz'):
    # !tar -xzf "$preprocessed_data_location" -C "$diffsvc_bin_location"
elif preprocessed_data_location.endswith('.tar.bz2'):
    # !tar -xjf "$preprocessed_data_location" -C "$diffsvc_bin_location"
else:
    !7za x "$preprocessed_data_location" -o$diffsvc_bin_location

print('Done!')

# %% [markdown]
# # Training Options/Parameters
# Unfortunately, you can not get away with no editing, not completely that is.

# %%
#@title #Step 3: Edit training parameters

K_step = 1000

batch_size = 12
decay_steps = 60000
lr = '0.0008'

#@markdown ---
#@markdown ###F0 extraction method
#@markdown Crepe is used for F0 extraction for data preprocessing, while it is of higher quality, it is slow, therefore set to false as default.

#@markdown Unchecking this while using the official repo will default to parselmouth, while using UtaUtaUtau's repo will use harvest.
use_crepe = True #@param {type: "boolean"}

#@markdown ---
#@markdown ###Set checkpoint interval
#@markdown As the name states, saves a checkpoint at an interval. When using GPU training, it runs quite fast, so try not to touch this, there's no point.
checkpoint_interval = 1000 #@param {type: "integer"}

#@markdown ---
#@markdown ###Disable FastSpeech2
#@markdown This disables fastspeech for decreased model size and faster training. This works best when the 44.1kHz vocoder is released.

#@markdown For 24kHz models, it is not suggested to use this, as your old models will become incompatible, and there's not much difference in training speed for 24kHz models anyway.
disable_fs2 = False #@param {type: "boolean"}

#@markdown ---
#@markdown ###Pretrain model usage
#@markdown This allows for faster training when in use. It is not recommended to use this if you have a sufficent amount of data. This uses the "nyaru" model.
use_pretrain_model = False #@param {type: "boolean"}

if use_pretrain_model:
  nyaru = SmartDL("https://github.com/haru0l/Diff-SVC-notebooks/releases/download/checkpoints/nyaru.zip", "/content/")
  nyaru.start()
  decay_steps = 174000
  lr = '0.00005'
  # %mkdir -p /content/diff-svc/pretrain/
  # !unzip /content/nyaru.zip -d /content/diff-svc/pretrain/
  if use_save_dir:
    # !cp -r /content/diff-svc/pretrain/nyaru/model_ckpt_steps_114000.ckpt {save_dir}
    else:
      # !cp -r /content/diff-svc/pretrain/nyaru/model_ckpt_steps_114000.ckpt /content/diff-svc/checkpoint/{singer_name}/

# !sed -i -r 's|(max_sentences:)(\s+)(.+)|\1\2{batch_size}|g' /content/diff-svc/training/config.yaml
# !sed -i -r 's|(decay_steps:)(\s+)(.+)|\1\2{decay_steps}|g' /content/diff-svc/training/config.yaml
# !sed -i -r 's|(lr:)(\s+)(.+)|\1\2{lr}|g' /content/diff-svc/training/config.yaml
# !sed -i -r 's|(K_step:)(\s+)(.+)|\1\2{K_step}|g' /content/diff-svc/training/config.yaml
# !sed -i -r 's|(max_sentences:)(\s+)(.+)|\1\2{batch_size}|g' /content/diff-svc/training/config.yaml
# !sed -i -r 's|(use_crepe:)(\s+)(.+)|\1\2{use_crepe}|g' /content/diff-svc/training/config.yaml
# !sed -i -r 's|(val_check_interval:)(\s+)(.+)|\1\2{checkpoint_interval}|g' /content/diff-svc/training/config.yaml
# !sed -i -r 's|(no_fs2:)(\s+)(.+)|\1\2{disable_fs2}|g' /content/diff-svc/training/config.yaml

#clear_output()
print('Done!')

# %% [markdown]
# # Training
# Finally, the dreaded part.

# %%
#@title #Step 4: Pre-processing
#@markdown This step is also known as data prep or feature generation, who cares?
#@markdown
# %cd "/content/diff-svc/"

os.environ['PYTHONPATH']='.'
# !CUDA_VISIBLE_DEVICES=0 python preprocessing/binarize.py --config training/config.yaml
# %cd "/content/diff-svc/data"
!7za -bso0 a "/content/{singer_name}_binary_data.7z" "binary/{singer_name}"
if not os.path.exists('/content/drive/MyDrive/diff-svc/data'):
    # !mkdir -p /content/drive/MyDrive/diff-svc/data
# !mv -v "/content/{singer_name}_binary_data.7z" /content/drive/MyDrive/diff-svc/data

# %%
#@title #Step 5-0: Setup for small datasets
#@markdown If your dataset is small (under 1 hour), each epoch will go by very fast and won't have enough time to train well, so if your dataset is considered small, run this cell.

#@markdown DO NOT RUN IF YOUR DATASET IS GOOD ENOUGH IN TERMS OF SIZE!

endless_ds = True
# !sed -i -r 's|(endless_ds:)(\s+)(.+)|\1\2{endless_ds}|g' /content/diff-svc/training/config.yaml
print("done!")

# %%
#@title #Step 5-1 Tensorboard (run before step 5)
#@markdown Shows training progress, go to the top right corner to set it to update the logs.

import datetime, os

if use_save_dir:
  # %tensorboard --load_fast=true --reload_interval=1 --reload_multifile=true --logdir="{save_dir}/lightning_logs/"
else:
  # %tensorboard --load_fast=true --reload_interval=1 --reload_multifile=true --logdir=/content/diff-svc/checkpoints/{singer_name}/lightning_logs/

# %%
#@title #Step 5: Training
#@markdown Yeah, it took THAT long to get here, colab is probably going to disconnect you at this point... unless you have pro ¯\\_(ツ)_/¯
# %cd "/content/diff-svc/"

os.environ['PYTHONPATH']='.'

# !CUDA_VISIBLE_DEVICES=0 python run.py --config training/config.yaml --exp_name $singer_name --reset
# Out:
# /content/diff-svc
# | Hparams chains:  ['training/config.yaml']
# | Hparams:
# K_step: 1000, accumulate_grad_batches: 1, audio_num_mel_bins: 80, audio_sample_rate: 24000, binarization_args: {'shuffle': False, 'with_align': True, 'with_f0': True, 'with_hubert': True, 'with_spk_embed': False, 'with_wav': False},
# binarizer_cls: preprocessing.SVCpre.SVCBinarizer, binary_data_dir: data/binary/carla, check_val_every_n_epoch: 10, choose_test_manually: False, clip_grad_norm: 1,
# config_path: training/config.yaml, content_cond_steps: [], cwt_add_f0_loss: False, cwt_hidden_size: 128, cwt_layers: 2,
# cwt_loss: l1, cwt_std_scale: 0.8, datasets: ['opencpop'], debug: False, dec_ffn_kernel_size: 9,
# dec_layers: 4, decay_steps: 174000, decoder_type: fft, dict_dir: , diff_decoder_type: wavenet,
# diff_loss_type: l2, dilation_cycle_length: 4, dropout: 0.1, ds_workers: 4, dur_enc_hidden_stride_kernel: ['0,2,3', '0,2,3', '0,1,3'],
# dur_loss: mse, dur_predictor_kernel: 3, dur_predictor_layers: 5, enc_ffn_kernel_size: 9, enc_layers: 4,
# encoder_K: 8, encoder_type: fft, endless_ds: True, f0_bin: 256, f0_max: 1100.0,
# f0_min: 50.0, ffn_act: gelu, ffn_padding: SAME, fft_size: 512, fmax: 12000,
# fmin: 30, fs2_ckpt: , gaussian_start: True, gen_dir_name: , gen_tgt_spk_id: -1,
# hidden_size: 256, hop_size: 128, hubert_gpu: True, hubert_path: checkpoints/hubert/hubert_soft.pt, infer: False,
# keep_bins: 80, lambda_commit: 0.25, lambda_energy: 0.0, lambda_f0: 1.0, lambda_ph_dur: 0.3,
# lambda_sent_dur: 1.0, lambda_uv: 1.0, lambda_word_dur: 1.0, load_ckpt: , log_interval: 100,
# loud_norm: False, lr: 5e-05, max_beta: 0.02, max_epochs: 3000, max_eval_sentences: 1,
# max_eval_tokens: 60000, max_frames: 42000, max_input_tokens: 60000, max_sentences: 18, max_tokens: 128000,
# max_updates: 1000000, mel_loss: ssim:0.5|l1:0.5, mel_vmax: 1.5, mel_vmin: -6.0, min_level_db: -120,
# no_fs2: True, norm_type: gn, num_ckpt_keep: 10, num_heads: 2, num_sanity_val_steps: 1,
# num_spk: 1, num_test_samples: 0, num_valid_plots: 10, optimizer_adam_beta1: 0.9, optimizer_adam_beta2: 0.98,
# out_wav_norm: False, pe_ckpt: checkpoints/0102_xiaoma_pe/model_ckpt_steps_60000.ckpt, pe_enable: False, perform_enhance: True, pitch_ar: False,
# pitch_enc_hidden_stride_kernel: ['0,2,5', '0,2,5', '0,2,5'], pitch_extractor: parselmouth, pitch_loss: l2, pitch_norm: log, pitch_type: frame,
# pndm_speedup: 10, pre_align_args: {'allow_no_txt': False, 'denoise': False, 'forced_align': 'mfa', 'txt_processor': 'zh_g2pM', 'use_sox': True, 'use_tone': False}, pre_align_cls: data_gen.singing.pre_align.SingingPreAlign, predictor_dropout: 0.5, predictor_grad: 0.1,
# predictor_hidden: -1, predictor_kernel: 5, predictor_layers: 5, prenet_dropout: 0.5, prenet_hidden_size: 256,
# pretrain_fs_ckpt: pretrain/nyaru/model_ckpt_steps_60000.ckpt, processed_data_dir: xxx, profile_infer: False, raw_data_dir: data/raw/carla, ref_norm_layer: bn,
# rel_pos: True, reset_phone_dict: True, residual_channels: 256, residual_layers: 20, save_best: False,
# save_ckpt: True, save_codes: ['configs', 'modules', 'src', 'utils'], save_f0: True, save_gt: False, schedule_type: linear,
# seed: 1234, sort_by_len: True, speaker_id: carla, spec_max: [-0.12500211596488953, 0.07279261201620102, 0.028414973989129066, 0.11313554644584656, 0.19998955726623535, 0.22962144017219543, 0.14575937390327454, 0.2659028470516205, 0.0931190550327301, 0.07465297728776932, 0.1985248625278473, 0.25567060708999634, 0.3346829414367676, 0.19323678314685822, 0.3226509988307953, 0.37346068024635315, 0.3808472454547882, 0.32908666133880615, 0.2494640350341797, 0.10136474668979645, 0.2297249287366867, 0.3338325023651123, 0.4122754633426666, 0.2848430871963501, 0.17263923585414886, 0.0299968384206295, -0.03687949478626251, -0.05422044172883034, -0.3362633287906647, -0.44702619314193726, -0.35943517088890076, -0.33071157336235046, -0.45126909017562866, -0.45621341466903687, -0.5115901231765747, -0.529975175857544, -0.5432918071746826, -0.6062136888504028, -0.6518750190734863, -0.656471312046051, -0.7557015419006348, -0.8615307807922363, -0.8330824971199036, -0.8663086891174316, -0.954477071762085, -0.8476677536964417, -0.8277950286865234, -0.7160253524780273, -0.857768177986145, -0.9784421324729919, -1.1046139001846313, -0.9874570965766907, -0.8725069761276245, -0.9308797717094421, -1.0431225299835205, -1.1368197202682495, -1.0711960792541504, -1.039237141609192, -1.2845895290374756, -1.404701828956604, -1.4862337112426758, -1.4204463958740234, -1.3104681968688965, -1.3023476600646973, -1.4434198141098022, -1.5149339437484741, -1.5000898838043213, -1.41994047164917, -1.7866841554641724, -1.553261399269104, -1.7017829418182373, -1.728261947631836, -1.6230270862579346, -1.6618359088897705, -1.6076956987380981, -1.9803764820098877, -1.9099775552749634, -2.1911988258361816, -2.2045719623565674, -2.2156827449798584], spec_min: [-4.539693832397461, -4.723130226135254, -4.8412370681762695, -5.508174419403076, -5.366244792938232, -5.841670989990234, -5.402697563171387, -4.854109764099121, -4.721842288970947, -4.464895248413086, -4.54591703414917, -4.500450611114502, -4.760902404785156, -5.094213485717773, -5.052940368652344, -5.3813042640686035, -5.101419448852539, -5.135878562927246, -5.219974517822266, -5.184974193572998, -5.812106609344482, -5.456861972808838, -5.47654914855957, -6.0, -5.99891996383667, -5.774034023284912, -5.311574935913086, -5.2225446701049805, -5.763267517089844, -5.597313404083252, -5.281798362731934, -5.168848514556885, -5.258108139038086, -4.89108943939209, -5.166292190551758, -4.9170918464660645, -4.909022331237793, -5.045351982116699, -5.224250793457031, -5.021782398223877, -5.007772445678711, -5.031034469604492, -5.046318054199219, -4.794182777404785, -4.781217575073242, -4.808889389038086, -5.414312839508057, -4.846102714538574, -4.9780802726745605, -4.697819709777832, -4.773293972015381, -4.7727437019348145, -4.808536052703857, -4.740602970123291, -4.7510857582092285, -4.63115119934082, -4.817991733551025, -4.795160293579102, -5.081129550933838, -4.813374042510986, -4.806460857391357, -5.6745710372924805, -6.0, -5.9866204261779785, -5.974940776824951, -5.94276237487793, -5.541895866394043, -5.924210548400879, -6.0, -6.0, -6.0, -6.0, -6.0, -6.0, -6.0, -6.0, -6.0, -6.0, -6.0, -6.0],
# spk_cond_steps: [], stop_token_weight: 5.0, task_cls: training.task.SVC_task.SVCTask, test_ids: [], test_input_dir: ,
# test_num: 0, test_prefixes: ['test'], test_set_name: test, timesteps: 1000, train_set_name: train,
# use_crepe: True, use_denoise: False, use_energy_embed: False, use_gt_dur: False, use_gt_f0: False,
# use_midi: False, use_nsf: True, use_pitch_embed: True, use_pos_embed: True, use_spk_embed: False,
# use_spk_id: False, use_split_spk_id: False, use_uv: False, use_var_enc: False, use_vec: False,
# val_check_interval: 1000, valid_num: 0, valid_set_name: valid, validate: False, vocoder: network.vocoders.hifigan.HifiGAN,
# vocoder_ckpt: checkpoints/0109_hifigan_bigpopcs_hop128, warmup_updates: 2000, wav2spec_eps: 1e-6, weight_decay: 0, win_size: 512,
# work_dir: /content/drive/Shareddrives/susdrive/haru_diff-svc/carla,
# | Mel losses: {'ssim': 0.5, 'l1': 0.5}
# | load HifiGAN:  checkpoints/0109_hifigan_bigpopcs_hop128/model_ckpt_steps_1512000.ckpt
# Removing weight norm...
# | Loaded model parameters from checkpoints/0109_hifigan_bigpopcs_hop128/model_ckpt_steps_1512000.ckpt.
# | HifiGAN device: cuda.
# 11/30 04:25:53 AM gpu available: True, used: True
# | model Trainable Parameters: 39.915M
# 11/30 04:25:55 AM model and trainer restored from checkpoint: /content/drive/Shareddrives/susdrive/haru_diff-svc/carla/model_ckpt_steps_112000.ckpt
# Validation sanity check:   0% 0/1 [00:00<?, ?batch/s]
# sample time step:   0% 0/100 [00:00<?, ?it/s]
# sample time step:   4% 4/100 [00:00<00:02, 33.36it/s]
# sample time step:   8% 8/100 [00:00<00:03, 29.54it/s]
# sample time step:  12% 12/100 [00:00<00:02, 31.41it/s]
# sample time step:  16% 16/100 [00:00<00:02, 33.37it/s]
# sample time step:  20% 20/100 [00:00<00:02, 34.03it/s]
# sample time step:  24% 24/100 [00:00<00:02, 34.43it/s]
# sample time step:  28% 28/100 [00:00<00:02, 34.69it/s]
# sample time step:  32% 32/100 [00:00<00:01, 34.89it/s]
# sample time step:  36% 36/100 [00:01<00:01, 34.91it/s]
# sample time step:  40% 40/100 [00:01<00:01, 34.45it/s]
# sample time step:  44% 44/100 [00:01<00:01, 34.34it/s]
# sample time step:  48% 48/100 [00:01<00:01, 34.48it/s]
# sample time step:  52% 52/100 [00:01<00:01, 34.62it/s]
# sample time step:  56% 56/100 [00:01<00:01, 34.72it/s]
# sample time step:  60% 60/100 [00:01<00:01, 34.71it/s]
# sample time step:  64% 64/100 [00:01<00:01, 34.74it/s]
# sample time step:  68% 68/100 [00:01<00:00, 34.69it/s]
# sample time step:  72% 72/100 [00:02<00:00, 34.64it/s]
# sample time step:  76% 76/100 [00:02<00:00, 34.53it/s]
# sample time step:  80% 80/100 [00:02<00:00, 34.47it/s]
# sample time step:  84% 84/100 [00:02<00:00, 34.55it/s]
# sample time step:  88% 88/100 [00:02<00:00, 34.71it/s]
# sample time step:  92% 92/100 [00:02<00:00, 34.60it/s]
# sample time step:  96% 96/100 [00:02<00:00, 34.63it/s]
# sample time step: 100% 100/100 [00:02<00:00, 34.33it/s]
# 11/30 04:26:04 AM NumExpr defaulting to 2 threads.
#
# ==============
#  valid results: {'total_loss': 0.0212, 'mel': 0.0212}
# ==============
#
# Epoch 1672: : 1001batch [19:27,  1.05batch/s, batch_size=2, lr=5e-5, mel=0.148, step=113000]
# Validating:   0% 0/5 [00:00<?, ?batch/s]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   5% 5/100 [00:00<00:02, 46.07it/s]
#
# sample time step:  10% 10/100 [00:00<00:02, 37.84it/s]
#
# sample time step:  14% 14/100 [00:00<00:02, 36.05it/s]
#
# sample time step:  18% 18/100 [00:00<00:02, 35.07it/s]
#
# sample time step:  22% 22/100 [00:00<00:02, 34.71it/s]
#
# sample time step:  26% 26/100 [00:00<00:02, 34.31it/s]
#
# sample time step:  30% 30/100 [00:00<00:02, 33.66it/s]
#
# sample time step:  34% 34/100 [00:00<00:02, 32.75it/s]
#
# sample time step:  38% 38/100 [00:01<00:01, 33.00it/s]
#
# sample time step:  42% 42/100 [00:01<00:01, 33.17it/s]
#
# sample time step:  46% 46/100 [00:01<00:01, 33.25it/s]
#
# sample time step:  50% 50/100 [00:01<00:01, 33.38it/s]
#
# sample time step:  54% 54/100 [00:01<00:01, 33.44it/s]
#
# sample time step:  58% 58/100 [00:01<00:01, 33.46it/s]
#
# sample time step:  62% 62/100 [00:01<00:01, 33.21it/s]
#
# sample time step:  66% 66/100 [00:01<00:01, 32.82it/s]
#
# sample time step:  70% 70/100 [00:02<00:00, 32.98it/s]
#
# sample time step:  74% 74/100 [00:02<00:00, 33.12it/s]
#
# sample time step:  78% 78/100 [00:02<00:00, 33.23it/s]
#
# sample time step:  82% 82/100 [00:02<00:00, 33.32it/s]
#
# sample time step:  86% 86/100 [00:02<00:00, 33.37it/s]
#
# sample time step:  90% 90/100 [00:02<00:00, 33.48it/s]
#
# sample time step:  94% 94/100 [00:02<00:00, 33.31it/s]
#
# sample time step: 100% 100/100 [00:02<00:00, 33.65it/s]
#
# Validating:  20% 1/5 [00:10<00:43, 10.77s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:03, 31.95it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 32.58it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 33.06it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.12it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.21it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.34it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.36it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.27it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.84it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.72it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.85it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.98it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.04it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.18it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.24it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.30it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.00it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.89it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.02it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.97it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.93it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.92it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.02it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.03it/s]
#
# Validating:  40% 2/5 [00:20<00:31, 10.35s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 32.03it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 31.33it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 32.16it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.61it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.88it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.07it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.07it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.20it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.85it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.80it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.85it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.00it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.08it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.08it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.05it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 32.87it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.83it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.90it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.93it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.03it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.18it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.20it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.24it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.93it/s]
#
# Validating:  60% 3/5 [00:31<00:20, 10.28s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 34.17it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 29.20it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.02it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 31.93it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.44it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.62it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 32.74it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 32.88it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.96it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.52it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.69it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.82it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.83it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 32.98it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.05it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.11it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 32.93it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.74it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.83it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.82it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.94it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.94it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.90it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 32.93it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.68it/s]
#
# Validating:  80% 4/5 [00:41<00:10, 10.19s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 37.71it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 31.67it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 32.71it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.09it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.22it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.35it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.33it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.45it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.38it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 33.02it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.90it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.08it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.20it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.28it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.32it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.33it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.32it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 33.16it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.02it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.04it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.05it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.09it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.04it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.12it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.17it/s]
#
# Validating: 100% 5/5 [00:51<00:00, 10.17s/batch]
# ==============
#  valid results: {'total_loss': 0.0011, 'mel': 0.0011}
# ==============
#
# Epoch 1672: : 1001batch [20:18,  1.05batch/s, batch_size=2, lr=5e-5, mel=0.148, step=113000]
#                                                 11/30 04:46:31 AM Epoch 01671@113000: saving model to /content/drive/Shareddrives/susdrive/haru_diff-svc/carla/model_ckpt_steps_113000.ckpt
# Epoch 1672: : 2000batch [39:47,  1.05s/batch, batch_size=2, lr=5e-5, mel=0.000338, step=113999]
# ==============
#  Epoch 1671 ended. Steps: 113999. {'total_loss': 0.0203, 'mel': 0.0203, 'batch_size': 10.0, 'lr': 0.0}
# ==============
#
# Epoch 1673: : 2001batch [39:48,  1.03s/batch, batch_size=2, lr=5e-5, mel=0.000527, step=114000]
# Validating:   0% 0/5 [00:00<?, ?batch/s]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   2% 2/100 [00:00<00:06, 14.86it/s]
#
# sample time step:   6% 6/100 [00:00<00:03, 27.46it/s]
#
# sample time step:   9% 9/100 [00:00<00:03, 25.86it/s]
#
# sample time step:  14% 14/100 [00:00<00:02, 34.06it/s]
#
# sample time step:  18% 18/100 [00:00<00:02, 34.76it/s]
#
# sample time step:  22% 22/100 [00:00<00:02, 33.56it/s]
#
# sample time step:  26% 26/100 [00:00<00:02, 35.43it/s]
#
# sample time step:  30% 30/100 [00:00<00:02, 34.88it/s]
#
# sample time step:  34% 34/100 [00:01<00:01, 33.83it/s]
#
# sample time step:  38% 38/100 [00:01<00:01, 33.61it/s]
#
# sample time step:  42% 42/100 [00:01<00:01, 33.51it/s]
#
# sample time step:  46% 46/100 [00:01<00:01, 33.55it/s]
#
# sample time step:  50% 50/100 [00:01<00:01, 33.61it/s]
#
# sample time step:  54% 54/100 [00:01<00:01, 33.61it/s]
#
# sample time step:  58% 58/100 [00:01<00:01, 33.64it/s]
#
# sample time step:  62% 62/100 [00:01<00:01, 33.45it/s]
#
# sample time step:  66% 66/100 [00:02<00:01, 33.19it/s]
#
# sample time step:  70% 70/100 [00:02<00:00, 33.12it/s]
#
# sample time step:  74% 74/100 [00:02<00:00, 33.15it/s]
#
# sample time step:  78% 78/100 [00:02<00:00, 33.18it/s]
#
# sample time step:  82% 82/100 [00:02<00:00, 33.28it/s]
#
# sample time step:  86% 86/100 [00:02<00:00, 33.23it/s]
#
# sample time step:  90% 90/100 [00:02<00:00, 33.52it/s]
#
# sample time step:  94% 94/100 [00:02<00:00, 33.52it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.01it/s]
#
# Validating:  20% 1/5 [00:12<00:50, 12.54s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 37.04it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 34.88it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 34.21it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.96it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.81it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.67it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.63it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.48it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.95it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.95it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.22it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.30it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.30it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.34it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.29it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.10it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.92it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.08it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.06it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.15it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.12it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.05it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.01it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.29it/s]
#
# Validating:  40% 2/5 [00:22<00:33, 11.13s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:03, 31.96it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 29.09it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.02it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 31.95it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.50it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.82it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.02it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.19it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.17it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.92it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.85it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.97it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.10it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.21it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.31it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.26it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.09it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.91it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.85it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.90it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.03it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.96it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.99it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 32.93it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.81it/s]
#
# Validating:  60% 3/5 [00:32<00:21, 10.70s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 35.68it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 34.33it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 33.88it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.53it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.46it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.43it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.43it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.24it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.63it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.57it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.74it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.02it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.12it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.02it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 32.91it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 32.60it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.47it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.63it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.67it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.87it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.94it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.88it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 32.90it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.98it/s]
#
# Validating:  80% 4/5 [00:43<00:10, 10.49s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 32.01it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 30.90it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 32.10it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.68it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.07it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.17it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.28it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.40it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.02it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.66it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.85it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.09it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.20it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.24it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.35it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.31it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.95it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.96it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.12it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.10it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.18it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.20it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.02it/s]
#
# Validating: 100% 5/5 [00:53<00:00, 10.43s/batch]
# ==============
#  valid results: {'total_loss': 0.0199, 'mel': 0.0199}
# ==============
#
# Epoch 1673: : 2001batch [40:42,  1.03s/batch, batch_size=2, lr=5e-5, mel=0.000527, step=114000]
#                                                 11/30 05:06:54 AM Epoch 01672@114000: saving model to /content/drive/Shareddrives/susdrive/haru_diff-svc/carla/model_ckpt_steps_114000.ckpt
# Epoch 1673: : 3001batch [1:00:11,  1.09batch/s, batch_size=2, lr=5e-5, mel=0.00772, step=115000]
# Validating:   0% 0/5 [00:00<?, ?batch/s]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   5% 5/100 [00:00<00:02, 45.27it/s]
#
# sample time step:  10% 10/100 [00:00<00:02, 37.38it/s]
#
# sample time step:  14% 14/100 [00:00<00:02, 35.86it/s]
#
# sample time step:  18% 18/100 [00:00<00:02, 35.02it/s]
#
# sample time step:  22% 22/100 [00:00<00:02, 34.51it/s]
#
# sample time step:  26% 26/100 [00:00<00:02, 34.18it/s]
#
# sample time step:  30% 30/100 [00:00<00:02, 32.81it/s]
#
# sample time step:  34% 34/100 [00:00<00:02, 32.52it/s]
#
# sample time step:  38% 38/100 [00:01<00:01, 32.80it/s]
#
# sample time step:  42% 42/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  46% 46/100 [00:01<00:01, 33.22it/s]
#
# sample time step:  50% 50/100 [00:01<00:01, 33.31it/s]
#
# sample time step:  54% 54/100 [00:01<00:01, 33.32it/s]
#
# sample time step:  58% 58/100 [00:01<00:01, 33.44it/s]
#
# sample time step:  62% 62/100 [00:01<00:01, 33.09it/s]
#
# sample time step:  66% 66/100 [00:01<00:01, 32.92it/s]
#
# sample time step:  70% 70/100 [00:02<00:00, 32.93it/s]
#
# sample time step:  74% 74/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  78% 78/100 [00:02<00:00, 33.32it/s]
#
# sample time step:  82% 82/100 [00:02<00:00, 33.32it/s]
#
# sample time step:  86% 86/100 [00:02<00:00, 33.27it/s]
#
# sample time step:  90% 90/100 [00:02<00:00, 33.38it/s]
#
# sample time step:  94% 94/100 [00:02<00:00, 33.27it/s]
#
# sample time step: 100% 100/100 [00:02<00:00, 33.58it/s]
#
# Validating:  20% 1/5 [00:10<00:42, 10.71s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 38.00it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 32.89it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 32.80it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.01it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.19it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.29it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.37it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.39it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.38it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 33.07it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.91it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.98it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.07it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.14it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.08it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.02it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.86it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.78it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.88it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.99it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.12it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.18it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.22it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.14it/s]
#
# Validating:  40% 2/5 [00:22<00:34, 11.57s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   3% 3/100 [00:00<00:03, 29.58it/s]
#
# sample time step:   6% 6/100 [00:00<00:03, 29.53it/s]
#
# sample time step:  10% 10/100 [00:00<00:02, 31.60it/s]
#
# sample time step:  14% 14/100 [00:00<00:02, 32.43it/s]
#
# sample time step:  18% 18/100 [00:00<00:02, 32.86it/s]
#
# sample time step:  22% 22/100 [00:00<00:02, 33.15it/s]
#
# sample time step:  26% 26/100 [00:00<00:02, 33.29it/s]
#
# sample time step:  30% 30/100 [00:00<00:02, 33.37it/s]
#
# sample time step:  34% 34/100 [00:01<00:01, 33.38it/s]
#
# sample time step:  38% 38/100 [00:01<00:01, 32.73it/s]
#
# sample time step:  42% 42/100 [00:01<00:01, 32.99it/s]
#
# sample time step:  46% 46/100 [00:01<00:01, 33.03it/s]
#
# sample time step:  50% 50/100 [00:01<00:01, 33.11it/s]
#
# sample time step:  54% 54/100 [00:01<00:01, 33.14it/s]
#
# sample time step:  58% 58/100 [00:01<00:01, 33.16it/s]
#
# sample time step:  62% 62/100 [00:01<00:01, 33.39it/s]
#
# sample time step:  66% 66/100 [00:02<00:01, 33.36it/s]
#
# sample time step:  70% 70/100 [00:02<00:00, 33.09it/s]
#
# sample time step:  74% 74/100 [00:02<00:00, 32.99it/s]
#
# sample time step:  78% 78/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  82% 82/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  86% 86/100 [00:02<00:00, 33.14it/s]
#
# sample time step:  90% 90/100 [00:02<00:00, 33.14it/s]
#
# sample time step:  94% 94/100 [00:02<00:00, 33.11it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.95it/s]
#
# Validating:  60% 3/5 [00:33<00:21, 10.91s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 32.83it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 33.26it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 33.39it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.41it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.38it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.40it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.37it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.36it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.92it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.84it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.89it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.82it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.02it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.12it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.02it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 32.81it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.70it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.71it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.77it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.78it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.88it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.85it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 32.90it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.97it/s]
#
# Validating:  80% 4/5 [00:43<00:10, 10.56s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 32.04it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 30.02it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.56it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.38it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.80it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.15it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.31it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.41it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.24it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.99it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 33.00it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.13it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.21it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.28it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.32it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.30it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.25it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.03it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.14it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.20it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.21it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.20it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.25it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.00it/s]
#
# Validating: 100% 5/5 [00:53<00:00, 10.48s/batch]
# ==============
#  valid results: {'total_loss': 0.0223, 'mel': 0.0223}
# ==============
#
# Epoch 1673: : 3001batch [1:01:04,  1.09batch/s, batch_size=2, lr=5e-5, mel=0.00772, step=115000]
#                                                 11/30 05:27:17 AM Epoch 01672@115000: saving model to /content/drive/Shareddrives/susdrive/haru_diff-svc/carla/model_ckpt_steps_115000.ckpt
# Epoch 1673: : 4000batch [1:20:34,  1.06s/batch, batch_size=2, lr=5e-5, mel=0.00237, step=115999]
# ==============
#  Epoch 1672 ended. Steps: 115999. {'total_loss': 0.0174, 'mel': 0.0174, 'batch_size': 10.0, 'lr': 0.0}
# ==============
#
# Epoch 1674: : 4001batch [1:20:35,  1.07s/batch, batch_size=2, lr=5e-5, mel=0.00085, step=116000]
# Validating:   0% 0/5 [00:00<?, ?batch/s]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   3% 3/100 [00:00<00:03, 26.32it/s]
#
# sample time step:   7% 7/100 [00:00<00:02, 31.83it/s]
#
# sample time step:  11% 11/100 [00:00<00:03, 28.77it/s]
#
# sample time step:  14% 14/100 [00:00<00:03, 28.41it/s]
#
# sample time step:  17% 17/100 [00:00<00:03, 25.82it/s]
#
# sample time step:  21% 21/100 [00:00<00:02, 29.81it/s]
#
# sample time step:  26% 26/100 [00:00<00:02, 34.43it/s]
#
# sample time step:  30% 30/100 [00:00<00:02, 33.75it/s]
#
# sample time step:  34% 34/100 [00:01<00:01, 33.74it/s]
#
# sample time step:  38% 38/100 [00:01<00:01, 33.73it/s]
#
# sample time step:  42% 42/100 [00:01<00:01, 33.62it/s]
#
# sample time step:  46% 46/100 [00:01<00:01, 33.43it/s]
#
# sample time step:  50% 50/100 [00:01<00:01, 33.05it/s]
#
# sample time step:  54% 54/100 [00:01<00:01, 33.07it/s]
#
# sample time step:  58% 58/100 [00:01<00:01, 33.24it/s]
#
# sample time step:  62% 62/100 [00:01<00:01, 33.17it/s]
#
# sample time step:  66% 66/100 [00:02<00:01, 33.27it/s]
#
# sample time step:  70% 70/100 [00:02<00:00, 33.36it/s]
#
# sample time step:  74% 74/100 [00:02<00:00, 33.40it/s]
#
# sample time step:  78% 78/100 [00:02<00:00, 33.39it/s]
#
# sample time step:  82% 82/100 [00:02<00:00, 33.12it/s]
#
# sample time step:  86% 86/100 [00:02<00:00, 33.06it/s]
#
# sample time step:  90% 90/100 [00:02<00:00, 33.21it/s]
#
# sample time step:  94% 94/100 [00:02<00:00, 33.24it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.60it/s]
#
# Validating:  20% 1/5 [00:11<00:44, 11.15s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:03, 31.87it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 30.04it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.58it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.36it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.76it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.02it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.15it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.22it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.07it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.88it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.96it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.10it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.24it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.14it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.09it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.16it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.05it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.97it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.86it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.93it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.02it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.11it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.13it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.90it/s]
#
# Validating:  40% 2/5 [00:21<00:31, 10.61s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 35.41it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 29.93it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.64it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.24it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.58it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.78it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.06it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.27it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.10it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.69it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.77it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.88it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.08it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.19it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.27it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.35it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.32it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.10it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.07it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.05it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.14it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.04it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.00it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.92it/s]
#
# Validating:  60% 3/5 [00:31<00:20, 10.35s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 38.18it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 34.08it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 33.63it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.48it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.47it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.51it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.50it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.48it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.37it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.94it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.99it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.11it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.17it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.19it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.07it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.88it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.77it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.82it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.96it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.04it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.02it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.09it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.20it/s]
#
# Validating:  80% 4/5 [00:43<00:10, 10.88s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   3% 3/100 [00:00<00:03, 26.71it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 34.00it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 33.71it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.63it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.74it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.61it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.62it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.67it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.40it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 33.26it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 33.09it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.25it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.31it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.36it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.44it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.47it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.36it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 33.18it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.99it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.09it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.17it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.11it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.22it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.31it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.28it/s]
#
# Validating: 100% 5/5 [00:53<00:00, 10.59s/batch]
# ==============
#  valid results: {'total_loss': 0.0038, 'mel': 0.0038}
# ==============
#
# Epoch 1674: : 4001batch [1:21:29,  1.07s/batch, batch_size=2, lr=5e-5, mel=0.00085, step=116000]
#                                                 11/30 05:47:41 AM Epoch 01673@116000: saving model to /content/drive/Shareddrives/susdrive/haru_diff-svc/carla/model_ckpt_steps_116000.ckpt
# Epoch 1674: : 5001batch [1:40:58,  1.08batch/s, batch_size=2, lr=5e-5, mel=0.0107, step=117000]
# Validating:   0% 0/5 [00:00<?, ?batch/s]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   5% 5/100 [00:00<00:02, 46.56it/s]
#
# sample time step:  10% 10/100 [00:00<00:02, 37.98it/s]
#
# sample time step:  14% 14/100 [00:00<00:02, 36.07it/s]
#
# sample time step:  18% 18/100 [00:00<00:02, 35.17it/s]
#
# sample time step:  22% 22/100 [00:00<00:02, 34.51it/s]
#
# sample time step:  26% 26/100 [00:00<00:02, 34.18it/s]
#
# sample time step:  30% 30/100 [00:00<00:02, 33.48it/s]
#
# sample time step:  34% 34/100 [00:00<00:01, 33.01it/s]
#
# sample time step:  38% 38/100 [00:01<00:01, 33.21it/s]
#
# sample time step:  42% 42/100 [00:01<00:01, 33.31it/s]
#
# sample time step:  46% 46/100 [00:01<00:01, 33.36it/s]
#
# sample time step:  50% 50/100 [00:01<00:01, 33.42it/s]
#
# sample time step:  54% 54/100 [00:01<00:01, 33.49it/s]
#
# sample time step:  58% 58/100 [00:01<00:01, 33.53it/s]
#
# sample time step:  62% 62/100 [00:01<00:01, 33.11it/s]
#
# sample time step:  66% 66/100 [00:01<00:01, 32.87it/s]
#
# sample time step:  70% 70/100 [00:02<00:00, 32.96it/s]
#
# sample time step:  74% 74/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  78% 78/100 [00:02<00:00, 33.29it/s]
#
# sample time step:  82% 82/100 [00:02<00:00, 33.33it/s]
#
# sample time step:  86% 86/100 [00:02<00:00, 33.33it/s]
#
# sample time step:  90% 90/100 [00:02<00:00, 33.44it/s]
#
# sample time step:  94% 94/100 [00:02<00:00, 33.07it/s]
#
# sample time step: 100% 100/100 [00:02<00:00, 33.64it/s]
#
# Validating:  20% 1/5 [00:10<00:43, 10.86s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 35.70it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 29.91it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.36it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.04it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.55it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.84it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.03it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.16it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.19it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.84it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.90it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.86it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.97it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.04it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.15it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.14it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.17it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 33.00it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.86it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.94it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.07it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.19it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.19it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.90it/s]
#
# Validating:  40% 2/5 [00:21<00:31, 10.62s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 38.04it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 32.43it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 32.69it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.90it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.00it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.08it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.07it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.22it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.23it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.90it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.81it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.95it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.07it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.08it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.15it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.14it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.03it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.83it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.75it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.87it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.92it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.10it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.09it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.15it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.04it/s]
#
# Validating:  60% 3/5 [00:31<00:20, 10.37s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 38.12it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 33.77it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 33.38it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.29it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.13it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.23it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.29it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.24it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.89it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.76it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.84it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.87it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 32.92it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 32.96it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.01it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 32.87it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.78it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.65it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.78it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.75it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.80it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.74it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 32.87it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.99it/s]
#
# Validating:  80% 4/5 [00:41<00:10, 10.31s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 33.05it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 33.30it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 33.46it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.54it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.60it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.53it/s]
#
# ...
#
# sample time step:  22% 22/100 [00:00<00:02, 34.47it/s]
#
# sample time step:  26% 26/100 [00:00<00:02, 34.23it/s]
#
# sample time step:  30% 30/100 [00:00<00:02, 32.46it/s]
#
# sample time step:  34% 34/100 [00:00<00:02, 32.52it/s]
#
# sample time step:  38% 38/100 [00:01<00:01, 32.95it/s]
#
# sample time step:  42% 42/100 [00:01<00:01, 33.07it/s]
#
# sample time step:  46% 46/100 [00:01<00:01, 33.25it/s]
#
# sample time step:  50% 50/100 [00:01<00:01, 33.33it/s]
#
# sample time step:  54% 54/100 [00:01<00:01, 33.48it/s]
#
# sample time step:  58% 58/100 [00:01<00:01, 33.34it/s]
#
# sample time step:  62% 62/100 [00:01<00:01, 32.85it/s]
#
# sample time step:  66% 66/100 [00:01<00:01, 32.63it/s]
#
# sample time step:  70% 70/100 [00:02<00:00, 32.89it/s]
#
# sample time step:  74% 74/100 [00:02<00:00, 33.05it/s]
#
# sample time step:  78% 78/100 [00:02<00:00, 33.15it/s]
#
# sample time step:  82% 82/100 [00:02<00:00, 33.25it/s]
#
# sample time step:  86% 86/100 [00:02<00:00, 33.31it/s]
#
# sample time step:  90% 90/100 [00:02<00:00, 33.34it/s]
#
# sample time step:  94% 94/100 [00:02<00:00, 33.03it/s]
#
# sample time step: 100% 100/100 [00:02<00:00, 33.49it/s]
#
# Validating:  20% 1/5 [00:10<00:43, 10.80s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 36.26it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 30.40it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.78it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.41it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.77it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.93it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.11it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.13it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.92it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.63it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.75it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.76it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.94it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 32.91it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 32.85it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.00it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.76it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.87it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.94it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.95it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.97it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.91it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.01it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.83it/s]
#
# Validating:  40% 2/5 [00:23<00:35, 11.96s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   3% 3/100 [00:00<00:03, 27.11it/s]
#
# sample time step:   7% 7/100 [00:00<00:02, 32.50it/s]
#
# sample time step:  11% 11/100 [00:00<00:02, 33.02it/s]
#
# sample time step:  15% 15/100 [00:00<00:02, 33.11it/s]
#
# sample time step:  19% 19/100 [00:00<00:02, 33.27it/s]
#
# sample time step:  23% 23/100 [00:00<00:02, 33.12it/s]
#
# sample time step:  27% 27/100 [00:00<00:02, 33.37it/s]
#
# sample time step:  31% 31/100 [00:00<00:02, 33.44it/s]
#
# sample time step:  35% 35/100 [00:01<00:01, 33.17it/s]
#
# sample time step:  39% 39/100 [00:01<00:01, 32.87it/s]
#
# sample time step:  43% 43/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  47% 47/100 [00:01<00:01, 33.11it/s]
#
# sample time step:  51% 51/100 [00:01<00:01, 33.18it/s]
#
# sample time step:  55% 55/100 [00:01<00:01, 33.19it/s]
#
# sample time step:  59% 59/100 [00:01<00:01, 33.14it/s]
#
# sample time step:  63% 63/100 [00:01<00:01, 33.27it/s]
#
# sample time step:  67% 67/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  71% 71/100 [00:02<00:00, 32.94it/s]
#
# sample time step:  75% 75/100 [00:02<00:00, 32.87it/s]
#
# sample time step:  79% 79/100 [00:02<00:00, 32.93it/s]
#
# sample time step:  83% 83/100 [00:02<00:00, 33.06it/s]
#
# sample time step:  87% 87/100 [00:02<00:00, 33.03it/s]
#
# sample time step:  91% 91/100 [00:02<00:00, 33.16it/s]
#
# sample time step:  95% 95/100 [00:02<00:00, 33.18it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.02it/s]
#
# Validating:  60% 3/5 [00:34<00:22, 11.50s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 36.77it/s]
#
# sample time step:   8% 8/100 [00:00<00:02, 34.56it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 34.15it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 33.80it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 33.59it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.33it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.16it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.06it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.67it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.82it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.90it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.99it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.99it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 32.87it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 32.91it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 32.80it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 32.60it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.58it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.75it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.75it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.84it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.81it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.74it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 32.68it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.98it/s]
#
# Validating:  80% 4/5 [00:44<00:10, 10.98s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:03, 31.93it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 30.50it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.88it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.57it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.90it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 33.14it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.26it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.34it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.04it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.81it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.15it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.30it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.40it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.41it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.41it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.17it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 33.08it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.14it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.23it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.28it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.27it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.25it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 33.02it/s]
#
# Validating: 100% 5/5 [00:54<00:00, 10.69s/batch]
# ==============
#  valid results: {'total_loss': 0.0034, 'mel': 0.0034}
# ==============
#
# Epoch 1678: : 13001batch [4:24:58,  1.06batch/s, batch_size=2, lr=5e-5, mel=0.000302, step=125000]
#                                                 11/30 08:51:11 AM Epoch 01677@125000: saving model to /content/drive/Shareddrives/susdrive/haru_diff-svc/carla/model_ckpt_steps_125000.ckpt
# 11/30 08:51:13 AM Delete ckpt: model_ckpt_steps_115000.ckpt
# Epoch 1678: : 14000batch [4:44:31,  1.05s/batch, batch_size=2, lr=5e-5, mel=0.0309, step=125999]
# ==============
#  Epoch 1677 ended. Steps: 125999. {'total_loss': 0.0124, 'mel': 0.0124, 'batch_size': 10.0, 'lr': 0.0}
# ==============
#
# Epoch 1679: : 14001batch [4:44:32,  1.08s/batch, batch_size=2, lr=5e-5, mel=0.00134, step=126000]
# Validating:   0% 0/5 [00:00<?, ?batch/s]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   2% 2/100 [00:00<00:05, 17.35it/s]
#
# sample time step:   5% 5/100 [00:00<00:04, 21.88it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 24.32it/s]
#
# sample time step:  12% 12/100 [00:00<00:03, 28.34it/s]
#
# sample time step:  15% 15/100 [00:00<00:03, 27.97it/s]
#
# sample time step:  21% 21/100 [00:00<00:02, 35.58it/s]
#
# sample time step:  25% 25/100 [00:00<00:02, 34.97it/s]
#
# sample time step:  29% 29/100 [00:00<00:02, 34.36it/s]
#
# sample time step:  33% 33/100 [00:01<00:01, 33.90it/s]
#
# sample time step:  37% 37/100 [00:01<00:01, 33.42it/s]
#
# sample time step:  41% 41/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  45% 45/100 [00:01<00:01, 33.15it/s]
#
# sample time step:  49% 49/100 [00:01<00:01, 33.29it/s]
#
# sample time step:  53% 53/100 [00:01<00:01, 33.36it/s]
#
# sample time step:  57% 57/100 [00:01<00:01, 33.45it/s]
#
# sample time step:  61% 61/100 [00:01<00:01, 33.52it/s]
#
# sample time step:  65% 65/100 [00:02<00:01, 33.41it/s]
#
# sample time step:  69% 69/100 [00:02<00:00, 33.26it/s]
#
# sample time step:  73% 73/100 [00:02<00:00, 32.99it/s]
#
# sample time step:  77% 77/100 [00:02<00:00, 32.99it/s]
#
# sample time step:  81% 81/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  85% 85/100 [00:02<00:00, 33.29it/s]
#
# sample time step:  89% 89/100 [00:02<00:00, 33.36it/s]
#
# sample time step:  93% 93/100 [00:02<00:00, 33.39it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.55it/s]
#
# Validating:  20% 1/5 [00:11<00:45, 11.30s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 34.17it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 29.46it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.31it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 31.95it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.33it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.54it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 32.72it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 32.85it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.92it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.65it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.74it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.90it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.96it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 32.99it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.17it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.13it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.90it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.96it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.93it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.00it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.12it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.24it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.80it/s]
#
# Validating:  40% 2/5 [00:21<00:32, 10.72s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:03, 32.00it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 29.48it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.27it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.12it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.71it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.92it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.09it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.28it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.06it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.77it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.81it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 33.03it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.12it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.22it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.28it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.29it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.09it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.95it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.80it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.78it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.90it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.95it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.04it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.12it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.83it/s]
#
# Validating:  60% 3/5 [00:31<00:20, 10.41s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 34.65it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 29.56it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 31.20it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 32.08it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.56it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.83it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 32.88it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 32.82it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 32.93it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.74it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.69it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.82it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 32.91it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 32.89it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 32.88it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 32.86it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 32.88it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.70it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 32.62it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 32.67it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 32.78it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 32.70it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 32.84it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 32.78it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.65it/s]
#
# Validating:  80% 4/5 [00:41<00:10, 10.36s/batch]
#
# sample time step:   0% 0/100 [00:00<?, ?it/s]
#
# sample time step:   4% 4/100 [00:00<00:02, 32.04it/s]
#
# sample time step:   8% 8/100 [00:00<00:03, 28.81it/s]
#
# sample time step:  12% 12/100 [00:00<00:02, 30.86it/s]
#
# sample time step:  16% 16/100 [00:00<00:02, 31.96it/s]
#
# sample time step:  20% 20/100 [00:00<00:02, 32.55it/s]
#
# sample time step:  24% 24/100 [00:00<00:02, 32.88it/s]
#
# sample time step:  28% 28/100 [00:00<00:02, 33.13it/s]
#
# sample time step:  32% 32/100 [00:00<00:02, 33.24it/s]
#
# sample time step:  36% 36/100 [00:01<00:01, 33.19it/s]
#
# sample time step:  40% 40/100 [00:01<00:01, 32.87it/s]
#
# sample time step:  44% 44/100 [00:01<00:01, 32.98it/s]
#
# sample time step:  48% 48/100 [00:01<00:01, 32.96it/s]
#
# sample time step:  52% 52/100 [00:01<00:01, 33.14it/s]
#
# sample time step:  56% 56/100 [00:01<00:01, 33.13it/s]
#
# sample time step:  60% 60/100 [00:01<00:01, 33.24it/s]
#
# sample time step:  64% 64/100 [00:01<00:01, 33.29it/s]
#
# sample time step:  68% 68/100 [00:02<00:00, 33.14it/s]
#
# sample time step:  72% 72/100 [00:02<00:00, 32.96it/s]
#
# sample time step:  76% 76/100 [00:02<00:00, 33.05it/s]
#
# sample time step:  80% 80/100 [00:02<00:00, 33.06it/s]
#
# sample time step:  84% 84/100 [00:02<00:00, 33.01it/s]
#
# sample time step:  88% 88/100 [00:02<00:00, 33.17it/s]
#
# sample time step:  92% 92/100 [00:02<00:00, 33.07it/s]
#
# sample time step:  96% 96/100 [00:02<00:00, 33.21it/s]
#
# sample time step: 100% 100/100 [00:03<00:00, 32.88it/s]
#
# Validating: 100% 5/5 [00:52<00:00, 10.30s/batch]
# ==============
#  valid results: {'total_loss': 0.0038, 'mel': 0.0038}
# ==============
#
# Epoch 1679: : 14001batch [4:45:24,  1.08s/batch, batch_size=2, lr=5e-5, mel=0.00134, step=126000]
#                                                 11/30 09:11:37 AM Epoch 01678@126000: saving model to /content/drive/Shareddrives/susdrive/haru_diff-svc/carla/model_ckpt_steps_126000.ckpt
# 11/30 09:11:38 AM Delete ckpt: model_ckpt_steps_116000.ckpt
# Epoch 1679: : 14013batch [4:45:40,  1.34s/batch, batch_size=2, lr=5e-5, mel=0.00293, step=126012]

# %%
#@title # Step 6: Package Model
#@markdown If you used a custom directory for saving your models please don't use this.

store_on_drive = True #@param {type: "boolean"}
from datetime import datetime, timezone
import glob

time_now = datetime.now(timezone.utc).strftime('%Y-%m-%d %H-%M-%S')

archive_name = f'{singer_name}_{time_now}'

if use_save_dir:
  # %cd {save_dir}
  # !zip -r "/content/{archive_name}.zip" ./ -x ./lighting_logs/\*
else:
  # %cd /content/diff-svc/checkpoints
  # !zip -r "/content/{archive_name}.zip" ./{singer_name} -x ./{singer_name}/lighting_logs/\*

if store_on_drive:
      if not os.path.exists('/content/drive/MyDrive/Diff-SVC_release'):
          # !mkdir /content/drive/MyDrive/Diff-SVC_release
      
      # !mv -v "/content/{archive_name}.zip" /content/drive/MyDrive/Diff-SVC_release

print('Done!')
